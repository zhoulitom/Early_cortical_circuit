# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#TPM values
dfc1_t = pd.read_csv('NBT_hiseq_linear_tpm_values.csv',index_col = 0)
dfc1_t.head(5)

dfc1_col = dfc1_t.copy()
dfc1_col.index
# Out:
# Index(['Hi_2338_1', 'Hi_2338_2', 'Hi_2338_3', 'Hi_2338_4', 'Hi_2338_5',
#        'Hi_2338_6', 'Hi_2338_7', 'Hi_2338_8', 'Hi_2338_9', 'Hi_2338_10',
#        ...
#        'Hi_GW16_17', 'Hi_GW16_18', 'Hi_GW16_19', 'Hi_GW16_20', 'Hi_GW16_21',
#        'Hi_GW16_22', 'Hi_GW16_23', 'Hi_GW16_24', 'Hi_GW16_25', 'Hi_GW16_26'],
#       dtype='object', length=301)

# %%
dfc1_col.head()
# Out:
#            A1BG  A1BG-AS1  A1CF  A2LD1  A2M  A2M-AS1  A2ML1  A2MP1  A4GALT  \
# Hi_2338_1  9.08      0.00  0.00   0.00  0.0      0.0   0.10    0.0    0.57
# Hi_2338_2  0.00      0.00  0.05   0.00  0.0      0.0   0.00    0.0    0.00
# Hi_2338_3  0.00      3.47  0.00   0.00  0.0      0.0   0.14    0.0    0.00
# Hi_2338_4  1.75      0.36  0.00   0.29  0.0      0.0   0.00    0.0    0.00
# Hi_2338_5  0.00      0.00  0.00   0.00  0.0      0.0   0.00    0.0    0.00
#
#            A4GNT  ...  ZWILCH   ZWINT   ZXDA  ZXDB   ZXDC  ZYG11A  ZYG11B  \
# Hi_2338_1    0.0  ...   15.35  137.97  10.94  0.08   0.84    0.88    6.06
# Hi_2338_2    0.0  ...   12.29   24.70   0.00  0.00  16.46    1.17   15.74
# Hi_2338_3    0.0  ...   22.46  292.01   0.00  0.00   0.78    1.08    1.35
# Hi_2338_4    0.0  ...   12.46  151.64   0.00  0.00   9.19    2.62   16.48
# Hi_2338_5    0.0  ...   52.60  429.75   0.00  0.00   0.36    1.22   24.66
#
#               ZYX  ZZEF1    ZZZ3
# Hi_2338_1   48.22   0.00  111.55
# ...

# %%
ax,fig = plt.subplots(figsize=(8,6))
df_target1 = dfc1_t.loc[:,['HTR1A','HTR1B','HTR1D','HTR1E','HTR1F','HTR2A','HTR2B','HTR2C','HTR4','HTR5A','HTR6','HTR7']]

# ax = sns.heatmap(df_target1, cmap="YlGnBu",vmin=0, vmax=100)#robust=False
# ax = sns.heatmap(df_target1, cmap="YlGnBu",robust=True)
cmap = sns.diverging_palette(240, 10, as_cmap=True)
ax = sns.heatmap(df_target1,cmap = cmap,robust=True)
#ax.set(xscale="log", yscale="log")
ax.figure.savefig('./output/NBT_serotonin_receptor1_robust09252020dpi150.png', dpi = 150, bbox_inches = 'tight')
