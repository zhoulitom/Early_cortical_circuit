# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dabest

print("We're using DABEST v{}".format(dabest.__version__))

df = pd.read_csv('summary_counts_cs.csv')#, index_col = 0
#print mean and std of IN and EX
# dfin = df[df['cell_type']=='IN']
# dfex = df[df['cell_type']=='EX']
# print('IN:\n',dfin.describe(),'\n','-_'*50)
# print('EX:\n',dfex.describe())
df.head()
df_freq = df
df_freq['id']=df_freq.index
df_freq.head()
plt.rcParams.update({'font.size': 6})

two_groups = dabest.load(df_freq, idx=("Control", "EMD",'TCB-2'),paired=False,id_col='id')
print(two_groups.mean_diff)
print(two_groups.mean_diff.statistical_tests)
# two_groups.mean_diff.plot(swarm_label="Calcium events per min",contrast_label="Mean diff. distribution", float_contrast=True,
#                            group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=True,
#                          group_summaries_offset=0.1,group_summary_kwargs = None,
#                           fig_size=(2,3.5),swarm_ylim=(0,1.2),raw_marker_size=9, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('Calcium_tcb_permin_dpi130_03092021.png',bbox_inches='tight',dpi=130)

plt.rcParams.update({'font.size': 12})
two_groups.mean_diff.plot(swarm_label="Pecentage of cells",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(8,6),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

plt.savefig('cell_tunel_experiments_140.png',bbox_inches='tight',dpi=140)
# Out:
# We're using DABEST v0.3.0
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Thu Jun 10 14:45:42 2021.
#
# The unpaired mean difference between Control and EMD is 0.00708 [95%CI 0.00134, 0.0149].
# The p-value of the two-sided permutation t-test is 0.0618.
#
# The unpaired mean difference between Control and TCB-2 is 0.0115 [95%CI 0.00238, 0.0274].
# The p-value of the two-sided permutation t-test is 0.0612.
#
# 5000 bootstrap samples were taken; the confidence interval is bias-corrected and accelerated.
# The p-value(s) reported are the likelihood(s) of observing the effect size(s),
# if the null hypothesis of zero difference is true.
# For each p-value, 5000 reshuffles of the control and test labels were performed.
#
# To get the results of all valid statistical tests, use `.mean_diff.statistical_tests`
#    control   test  control_N  test_N      effect_size  is_paired  difference  \
# 0  Control    EMD          9       9  mean difference      False    0.007080
# ...

# %%
#summary_counts_individuals.csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dabest

print("We're using DABEST v{}".format(dabest.__version__))

df = pd.read_csv('summary_counts_individuals.csv')#, index_col = 0
#print mean and std of IN and EX
# dfin = df[df['cell_type']=='IN']
# dfex = df[df['cell_type']=='EX']
# print('IN:\n',dfin.describe(),'\n','-_'*50)
# print('EX:\n',dfex.describe())
df.head()
df_freq = df
df_freq['id']=df_freq.index
df_freq.head()
plt.rcParams.update({'font.size': 6})

two_groups = dabest.load(df_freq, idx=("Control", "EMD",'TCB-2'),paired=False,id_col='id')
print(two_groups.mean_diff)
print(two_groups.mean_diff.statistical_tests)
# two_groups.mean_diff.plot(swarm_label="Calcium events per min",contrast_label="Mean diff. distribution", float_contrast=True,
#                            group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=True,
#                          group_summaries_offset=0.1,group_summary_kwargs = None,
#                           fig_size=(2,3.5),swarm_ylim=(0,1.2),raw_marker_size=9, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('Calcium_tcb_permin_dpi130_03092021.png',bbox_inches='tight',dpi=130)

plt.rcParams.update({'font.size': 12})
two_groups.mean_diff.plot(swarm_label="GFP Area%",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(7,3.5),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('EMD_dpi80_03092021_nonpair_wide140.png',bbox_inches='tight',dpi=140)
# Out:
# We're using DABEST v0.3.0
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Thu Jun 10 14:24:35 2021.
#
# The unpaired mean difference between Control and EMD is 0.00708 [95%CI -0.00398, 0.0149].
# The p-value of the two-sided permutation t-test is 0.239.
#
# The unpaired mean difference between Control and TCB-2 is 0.0115 [95%CI -0.00597, 0.0219].
# The p-value of the two-sided permutation t-test is 0.262.
#
# 5000 bootstrap samples were taken; the confidence interval is bias-corrected and accelerated.
# The p-value(s) reported are the likelihood(s) of observing the effect size(s),
# if the null hypothesis of zero difference is true.
# For each p-value, 5000 reshuffles of the control and test labels were performed.
#
# To get the results of all valid statistical tests, use `.mean_diff.statistical_tests`
#    control   test  control_N  test_N      effect_size  is_paired  difference  \
# 0  Control    EMD          3       3  mean difference      False    0.007080
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dabest

print("We're using DABEST v{}".format(dabest.__version__))

df = pd.read_csv('summary_counts_cs.csv')#, index_col = 0
#print mean and std of IN and EX
# dfin = df[df['cell_type']=='IN']
# dfex = df[df['cell_type']=='EX']
# print('IN:\n',dfin.describe(),'\n','-_'*50)
# print('EX:\n',dfex.describe())
df.head()
df_freq = df
df_freq['id']=df_freq.index
df_freq.head()
plt.rcParams.update({'font.size': 6})

two_groups = dabest.load(df_freq, idx=("control", "emd",'et','Tcb-2'),paired=False,id_col='id')
print(two_groups.mean_diff)
print(two_groups.mean_diff.statistical_tests)
# two_groups.mean_diff.plot(swarm_label="Calcium events per min",contrast_label="Mean diff. distribution", float_contrast=True,
#                            group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=True,
#                          group_summaries_offset=0.1,group_summary_kwargs = None,
#                           fig_size=(2,3.5),swarm_ylim=(0,1.2),raw_marker_size=9, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('Calcium_tcb_permin_dpi130_03092021.png',bbox_inches='tight',dpi=130)

plt.rcParams.update({'font.size': 12})
two_groups.mean_diff.plot(swarm_label="GFP Area%",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(7,3.5),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('EMD_dpi80_03092021_nonpair_wide140.png',bbox_inches='tight',dpi=140)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dabest

print("We're using DABEST v{}".format(dabest.__version__))

df = pd.read_csv('summary_counts.csv')#, index_col = 0
#print mean and std of IN and EX
# dfin = df[df['cell_type']=='IN']
# dfex = df[df['cell_type']=='EX']
# print('IN:\n',dfin.describe(),'\n','-_'*50)
# print('EX:\n',dfex.describe())
df.head()
# Out:
# We're using DABEST v0.3.0
#     control       emd        et     Tcb-2
# 0  0.012478  0.005629  0.034672  0.029455
# 1  0.007429  0.003704  0.019200  0.036623
# 2  0.009444  0.016645  0.021598  0.026114
# 3  0.010791  0.009259  0.026515  0.034014
# 4  0.006993  0.023508  0.031481  0.024904

# %%
df_freq = df
df_freq['id']=df_freq.index
df_freq.head()
# Out:
#     control       emd        et     Tcb-2  id
# 0  0.012478  0.005629  0.034672  0.029455   0
# 1  0.007429  0.003704  0.019200  0.036623   1
# 2  0.009444  0.016645  0.021598  0.026114   2
# 3  0.010791  0.009259  0.026515  0.034014   3
# 4  0.006993  0.023508  0.031481  0.024904   4

# %%
df_freq.describe()
# Out:
#          control        emd         et      Tcb-2         id
# count  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    0.011219   0.015575   0.021916   0.021882   7.000000
# std     0.004707   0.013113   0.010229   0.011620   4.472136
# min     0.000000   0.000000   0.008518   0.000000   0.000000
# 25%     0.009206   0.004666   0.013591   0.017464   3.500000
# 50%     0.011442   0.013208   0.021598   0.024904   7.000000
# 75%     0.012930   0.024489   0.026245   0.028203  10.500000
# max     0.021756   0.040621   0.044349   0.037551  14.000000

# %%
plt.rcParams.update({'font.size': 6})

two_groups = dabest.load(df_freq, idx=("control", "emd",'et','Tcb-2'),paired=False,id_col='id')
print(two_groups.mean_diff)
print(two_groups.mean_diff.statistical_tests)
# two_groups.mean_diff.plot(swarm_label="Calcium events per min",contrast_label="Mean diff. distribution", float_contrast=True,
#                            group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=True,
#                          group_summaries_offset=0.1,group_summary_kwargs = None,
#                           fig_size=(2,3.5),swarm_ylim=(0,1.2),raw_marker_size=9, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('Calcium_tcb_permin_dpi130_03092021.png',bbox_inches='tight',dpi=130)
# Out:
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Wed Jun  9 14:31:24 2021.
#
# The unpaired mean difference between control and emd is 0.00436 [95%CI -0.00205, 0.0117].
# The p-value of the two-sided permutation t-test is 0.225.
#
# The unpaired mean difference between control and et is 0.0107 [95%CI 0.00545, 0.0165].
# The p-value of the two-sided permutation t-test is 0.001.
#
# The unpaired mean difference between control and Tcb-2 is 0.0107 [95%CI 0.00391, 0.0164].
# The p-value of the two-sided permutation t-test is 0.003.
#
# 5000 bootstrap samples were taken; the confidence interval is bias-corrected and accelerated.
# The p-value(s) reported are the likelihood(s) of observing the effect size(s),
# if the null hypothesis of zero difference is true.
# For each p-value, 5000 reshuffles of the control and test labels were performed.
#
# To get the results of all valid statistical tests, use `.mean_diff.statistical_tests`
# ...

# %%
plt.rcParams.update({'font.size': 12})
two_groups.mean_diff.plot(swarm_label="GFP Area%",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(7,3.5),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('EMD_dpi80_03092021_nonpair_wide140.png',bbox_inches='tight',dpi=140)
# Out:
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# ...

# %%
df = pd.read_csv('summary_counts_cs.csv')#, index_col = 0
#print mean and std of IN and EX
# dfin = df[df['cell_type']=='IN']
# dfex = df[df['cell_type']=='EX']
# print('IN:\n',dfin.describe(),'\n','-_'*50)
# print('EX:\n',dfex.describe())
df.head()
df_freq = df
df_freq['id']=df_freq.index
df_freq.head()
plt.rcParams.update({'font.size': 6})

two_groups = dabest.load(df_freq, idx=("control", "emd",'et','Tcb-2'),paired=False,id_col='id')
print(two_groups.mean_diff)
print(two_groups.mean_diff.statistical_tests)
# two_groups.mean_diff.plot(swarm_label="Calcium events per min",contrast_label="Mean diff. distribution", float_contrast=True,
#                            group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=True,
#                          group_summaries_offset=0.1,group_summary_kwargs = None,
#                           fig_size=(2,3.5),swarm_ylim=(0,1.2),raw_marker_size=9, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('Calcium_tcb_permin_dpi130_03092021.png',bbox_inches='tight',dpi=130)

plt.rcParams.update({'font.size': 12})
two_groups.mean_diff.plot(swarm_label="GFP Area%",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(7,3.5),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

# plt.savefig('EMD_dpi80_03092021_nonpair_wide140.png',bbox_inches='tight',dpi=140)
# Out:
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Wed Jun  9 14:40:16 2021.
#
# The unpaired mean difference between control and emd is 0.00436 [95%CI 2e-05, 0.00708].
# The p-value of the two-sided permutation t-test is 0.178.
#
# The unpaired mean difference between control and et is 0.0107 [95%CI 0.00724, 0.0155].
# The p-value of the two-sided permutation t-test is 0.0674.
#
# The unpaired mean difference between control and Tcb-2 is 0.0107 [95%CI 0.00525, 0.019].
# The p-value of the two-sided permutation t-test is 0.0674.
#
# 5000 bootstrap samples were taken; the confidence interval is bias-corrected and accelerated.
# The p-value(s) reported are the likelihood(s) of observing the effect size(s),
# if the null hypothesis of zero difference is true.
# For each p-value, 5000 reshuffles of the control and test labels were performed.
#
# To get the results of all valid statistical tests, use `.mean_diff.statistical_tests`
# ...

# %%
# for mecherry signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dabest

# %%
df1 = pd.read_csv('emd_mcherry_03102021.csv')#, index_col = 0
df1.head()
# Out:
#    CONTROL  EMD10   EMD25   EMD50
# 0   12.326  8.664   9.466  13.054
# 1   10.393  5.580  14.059  11.513
# 2    7.597  9.614   8.438  16.089
# 3   12.807  3.070  10.662   9.497
# 4    4.798  9.656   6.265   7.675

# %%
two_groups1 = dabest.load(df1, idx=("CONTROL", "EMD10",'EMD25','EMD50'),paired=False,id_col='id')
print(two_groups1.mean_diff)
print(two_groups1.mean_diff.statistical_tests)
# Out:
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Wed Mar 10 13:00:31 2021.
#
# The unpaired mean difference between CONTROL and EMD10 is -2.75 [95%CI -6.2, 1.64].
# The p-value of the two-sided permutation t-test is 0.211.
#
# The unpaired mean difference between CONTROL and EMD25 is -1.65 [95%CI -4.69, 1.16].
# The p-value of the two-sided permutation t-test is 0.413.
#
# The unpaired mean difference between CONTROL and EMD50 is 0.489 [95%CI -2.88, 3.34].
# The p-value of the two-sided permutation t-test is 0.784.
#
# 5000 bootstrap samples were taken; the confidence interval is bias-corrected and accelerated.
# The p-value(s) reported are the likelihood(s) of observing the effect size(s),
# if the null hypothesis of zero difference is true.
# For each p-value, 5000 reshuffles of the control and test labels were performed.
#
# To get the results of all valid statistical tests, use `.mean_diff.statistical_tests`
# ...

# %%
plt.rcParams.update({'font.size': 12})
two_groups1.mean_diff.plot(swarm_label="mCherry Area%",contrast_label="Mean difference", float_contrast=True,
                           group_summaries = 'mean_sd',slopegraph_kwargs={'linewidth':1, 'alpha':0.9},show_pairs=False,
                         group_summaries_offset=0.1,group_summary_kwargs = None,
                          fig_size=(7,3.5),swarm_ylim=(0,30),raw_marker_size=7, es_marker_size=10)#group_summaries = 'mean_sd',,swarm_ylim=(0,20),contrast_ylim =(,6)group_summary_kwargs = {'lw':2, 'alpha':1, 'zorder':1},

plt.savefig('mcherry_dpi140_03092021_nonpair_wide140.png',bbox_inches='tight',dpi=140)
# Out:
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# C:\Users\zhouli\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# ...
